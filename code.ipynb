# %%
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=4>

# %%
from PIL import Image
import skimage
import numpy as np

img = Image.open('dataset/data/kodak/kodim15.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x512 at 0x7F9DC1FEEA90>

# %%
(25/255)**2
# Out:
# 0.009611687812379853

# %%
im_array = skimage.util.random_noise(np.asarray(img),mode="gaussian",mean=0,var=(25/255)**2)
Image.fromarray(np.uint8(im_array*255))
# Out:
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7F9DC2D618B0>
